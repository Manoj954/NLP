# %%
from newsapi import NewsApiClient

# %%
# Init
newsapi = NewsApiClient(api_key='57b09c8dcd91403d98299a5b3fc6607a')

# %%
# /v2/top-headlines
top_headlines = newsapi.get_top_headlines(q='bitcoin',
                                          sources='bbc-news,the-verge',
                                          language='en')

# %%
# /v2/everything
all_articles = newsapi.get_everything(q='bitcoin',
                                      sources='bbc-news,the-verge',
                                      domains='bbc.co.uk,techcrunch.com',
                                      from_param='2019-02-22',
                                      to='2019-03-12',
                                      language='en',
                                      sort_by='relevancy',
                                      page=10)

# %%
# /v2/sources
sources = newsapi.get_sources()

# %%
sources
# Out:
# {'sources': [{'category': 'general',
#    'country': 'us',
#    'description': 'Your trusted source for breaking news, analysis, exclusive interviews, headlines, and videos at ABCNews.com.',
#    'id': 'abc-news',
#    'language': 'en',
#    'name': 'ABC News',
#    'url': 'https://abcnews.go.com'},
#   {'category': 'general',
#    'country': 'au',
#    'description': "Australia's most trusted source of local, national and world news. Comprehensive, independent, in-depth analysis, the latest business, sport, weather and more.",
#    'id': 'abc-news-au',
#    'language': 'en',
#    'name': 'ABC News (AU)',
#    'url': 'http://www.abc.net.au/news'},
#   {'category': 'general',
#    'country': 'no',
#    'description': 'Norges ledende nettavis med alltid oppdaterte nyheter innenfor innenriks, utenriks, sport og kultur.',
#    'id': 'aftenposten',
#    'language': 'no',
#    'name': 'Aftenposten',
#    'url': 'https://www.aftenposten.no'},
#   {'category': 'general',
# ...

# %%
all_articles
# Out:
# {'articles': [], 'status': 'ok', 'totalResults': 12}

# %%
top_headlines
# Out:
# {'articles': [], 'status': 'ok', 'totalResults': 0}

# %%
all_headlines=newsapi.get_top_headlines(country='us')

# %%
all_headlines
# Out:
# {'articles': [{'author': 'https://www.facebook.com/bbcnews',
#    'content': 'Image copyright EPA Image caption The threat level was temporarily raised to its highest level after the shooting A man has admitted to killing three people on a tram in Utrecht and said he acted alone, Dutch prosecutors say. Turkish-born Gokmen Tanis, 37, wo… [+1554 chars]',
#    'description': 'Turkish-born Gokmen Tanis says he acted alone in the killing of three people.',
#    'publishedAt': '2019-03-22T16:52:30Z',
#    'source': {'id': None, 'name': 'Bbc.com'},
#    'title': 'Utrecht shooting: Suspect Tanis admits deadly tram attack - BBC News',
#    'url': 'https://www.bbc.com/news/world-europe-47665191',
#    'urlToImage': 'https://ichef.bbci.co.uk/news/1024/branded_news/1226B/production/_106074347_hi053031812.jpg'},
#   {'author': None,
# ...

# %%
import pandas as pd

# %%
df=pd.DataFrame(all_headlines)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 3 columns):
# articles        20 non-null object
# status          20 non-null object
# totalResults    20 non-null int64
# dtypes: int64(1), object(2)
# memory usage: 560.0+ bytes

# %%
df_allContents=pd.DataFrame(df.articles)

# %%
df_allContents.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 1 columns):
# articles    20 non-null object
# dtypes: object(1)
# memory usage: 240.0+ bytes

# %%
df_allContents=pd.DataFrame(df_allContents.articles)

# %%
df_new=df_allContents.apply(lambda x:''.join(str(x)),axis=0)

# %%
df_allContents.to_csv(path+'\\pandas1.txt', header=None, index=None, sep='~', mode='a')

# %%
sample=pd.read_csv(path+"\\pandas1.txt",header=None, delimiter='~')

# %%
sample[0][0]
# Out:
# "{'urlToImage': 'https://ichef.bbci.co.uk/news/1024/branded_news/1226B/production/_106074347_hi053031812.jpg', 'source': {'id': None, 'name': 'Bbc.com'}, 'content': 'Image copyright EPA Image caption The threat level was temporarily raised to its highest level after the shooting A man has admitted to killing three people on a tram in Utrecht and said he acted alone, Dutch prosecutors say. Turkish-born Gokmen Tanis, 37, wo… [+1554 chars]', 'description': 'Turkish-born Gokmen Tanis says he acted alone in the killing of three people.', 'publishedAt': '2019-03-22T16:52:30Z', 'title': 'Utrecht shooting: Suspect Tanis admits deadly tram attack - BBC News', 'author': 'https://www.facebook.com/bbcnews', 'url': 'https://www.bbc.com/news/world-europe-47665191'}"

# %%
print(str(df_new[0]))
# Out:
# 0     {'urlToImage': 'https://ichef.bbci.co.uk/news/...
# 1     {'urlToImage': 'https://static.foxnews.com/fox...
# 2     {'urlToImage': 'https://img.huffingtonpost.com...
# 3     {'urlToImage': 'https://fm.cnbc.com/applicatio...
# 4     {'urlToImage': 'https://cdn.vox-cdn.com/thumbo...
# 5     {'urlToImage': 'https://www.washingtonpost.com...
# 6     {'urlToImage': 'https://i.dailymail.co.uk/1s/2...
# 7     {'urlToImage': 'https://cdn.vox-cdn.com/thumbo...
# 8     {'urlToImage': 'https://amp.businessinsider.co...
# 9     {'urlToImage': 'https://media.npr.org/assets/i...
# 10    {'urlToImage': 'https://www.aljazeera.com/mrit...
# 11    {'urlToImage': 'https://media2.s-nbcnews.com/j...
# 12    {'urlToImage': 'https://cnet4.cbsistatic.com/i...
# 13    {'urlToImage': 'https://media.npr.org/assets/i...
# 14    {'urlToImage': 'https://cdn.cnn.com/cnnnext/da...
# 15    {'urlToImage': None, 'source': {'id': 'bloombe...
# 16    {'urlToImage': 'https://o.aolcdn.com/images/di...
# ...

# %%
W_articles = newsapi.get_everything(q='marvel',page_size=100)

# %%
wdf=pd.DataFrame(W_articles)

# %%
wdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 3 columns):
# articles        100 non-null object
# status          100 non-null object
# totalResults    100 non-null int64
# dtypes: int64(1), object(2)
# memory usage: 2.4+ KB

# %%
category=["business","entertainment","general","health","science","sports","technology"]

# %%
import os

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints', 'News Classification.ipynb', 'NewsApi.ipynb']

# %%
path="D:\\Projects\\Data\\News\\Data\\"

# %%
for cat in category:
    print(cat)
    all_headlines=newsapi.get_top_headlines(category=cat,page_size=100)
    df=pd.DataFrame(all_headlines)
    df_allContents=pd.DataFrame(df.articles)
    df_allContents.to_csv(path+'\\'+str(cat)+'.txt', header=None, index=None, sep='~', mode='a')
# Out:
# business
# entertainment
# general
# health
# science
# sports
# technology

# %%
df_allContents
# Out:
#                                              articles
# 0   {'urlToImage': 'https://cdn.cnn.com/cnnnext/da...
# 1   {'urlToImage': 'https://icdn3.digitaltrends.co...
# 2   {'urlToImage': 'https://www.elbayan-news.com/t...
# 3   {'urlToImage': 'https://i-invdn-com.akamaized....
# 4   {'urlToImage': 'https://i-invdn-com.akamaized....
# 5   {'urlToImage': 'https://files.merca20.com/uplo...
# 6   {'urlToImage': None, 'source': {'id': None, 'n...
# 7   {'urlToImage': 'https://static.deia.eus/images...
# 8   {'urlToImage': 'https://s4.reutersmedia.net/re...
# 9   {'urlToImage': 'https://d.wpimg.pl/2109148552-...
# 10  {'urlToImage': 'https://dotemirates-media.s3-e...
# 11  {'urlToImage': 'https://imbo.vgc.no/users/e24/...
# 12  {'urlToImage': 'https://www.plurielle.ma/wp-co...
# 13  {'urlToImage': 'https://media.novinky.cz/980/7...
# 14  {'urlToImage': 'https://www.americaeconomia.co...
# 15  {'urlToImage': 'https://i-invdn-com.akamaized....
# ...

# %%
df_allContents.to_csv(path+'\\cat1.txt', header=None, index=None, sep='~', mode='a')

# %%
from datetime import datetime
# Out:
# '2019-03-23 01:02:33'

# %%
datetime.now().strftime('%Y_%m_%d_%H_%M_%S')
# Out:
# '2019_03_23_01_03_02'
